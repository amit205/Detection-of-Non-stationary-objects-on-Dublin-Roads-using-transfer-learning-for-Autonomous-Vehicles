# %%
# !pwd
# Out:
# /home/amit_domainer_gmail_com/models/research/object_detection

# %%
# %cd /home/amit_domainer_gmail_com/models/research
# Out:
# /home/amit_domainer_gmail_com/models/research

# %%
# %set_env PYTHONPATH=/home/amit_domainer_gmail_com/models/research:/home/amit_domainer_gmail_com/models/research/slim
# Out:
# env: PYTHONPATH=/home/amit_domainer_gmail_com/models/research:/home/amit_domainer_gmail_com/models/research/slim

# %%
# !python object_detection/builders/model_builder_test.py
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /home/amit_domainer_gmail_com/models/research/slim/nets/inception_resnet_v2.py:374: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/amit_domainer_gmail_com/models/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# Running tests under Python 2.7.13: /usr/bin/python
# [ RUN      ] ModelBuilderTest.test_create_experimental_model
# [       OK ] ModelBuilderTest.test_create_experimental_model
# ...

# %%
# !pwd
# Out:
# /home/amit_domainer_gmail_com/models/research

# %%
# %cd object_detection
# Out:
# /home/amit_domainer_gmail_com/models/research/object_detection

# %%
#!python3 model_main.py --logtostderr --model_dir=training/ --pipeline_config_path=training/faster_rcnn_inception_v2_pets.config

# !python3 model_main.py --logtostderr --model_dir=training-ssd/ --pipeline_config_path=training-ssd/ssd_mobilenet_v2_coco-1.config
# Out:
# /home/amit_domainer_gmail_com/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/amit_domainer_gmail_com/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/amit_domainer_gmail_com/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
